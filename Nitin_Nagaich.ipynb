# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from glob import glob
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/drive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/drive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN/ISIC/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/CNN/ISIC/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2255
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,           # 20% for validation
    subset="training",              # Specify this subset is for training
    seed=123,
    image_size=(img_height, img_width),# Resize images to (180, 180)
    batch_size=batch_size
)
# Out:
# Found 2255 files belonging to 9 classes.
# Using 1804 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,           # 20% for validation
    subset="validation",              # Specify this subset is for training
    seed=123,
    image_size=(img_height, img_width),# Resize images to (180, 180)
    batch_size=batch_size
)
# Out:
# Found 2255 files belonging to 9 classes.
# Using 451 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    image_size=(img_height, img_width),# Resize images to (180, 180)
    batch_size=batch_size
)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

def plot_images(dataset):
  # Dictionary to store image from each class
  images_per_class = {}

  for images,labels in dataset:
    for image,label in zip(images,labels):
      class_name = class_names[label]
      if class_name not in images_per_class:
          images_per_class[class_name] = image
      if len(images_per_class) == len(class_names):  # Stop when we have one example for each class
          break
    if len(images_per_class) == len(class_names):
        break

  # Plot one image per class
  plt.figure(figsize=(10, 10))
  for i, (class_name, image) in enumerate(images_per_class.items()):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(image.numpy().astype("uint8"))
      plt.title(class_name)
      plt.axis("off")
  plt.show()

plot_images(train_ds)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
input_shape = (180,180,3)

inputs = keras.Input(shape=input_shape)
lr = layers.Rescaling(scale=1.0/255)(inputs)

lr = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu")(lr)
lr = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu")(lr)
lr = layers.MaxPooling2D(pool_size=(2,2))(lr)
lr = layers.BatchNormalization()(lr)

lr = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu")(lr)
lr = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu")(lr)
lr = layers.MaxPooling2D(pool_size=(2,2))(lr)
lr = layers.BatchNormalization()(lr)

lr = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu")(lr)

lr = layers.GlobalAveragePooling2D()(lr)
lr = layers.Flatten()(lr)
lr = layers.Dense(32, activation="relu")(lr)
lr = layers.Dense(16, activation="relu")(lr)

outputs = layers.Dense(len(class_names), activation="softmax")(lr)

model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 180, 180, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 90, 90, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 90, 90, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 90, 90, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 45, 45, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 45, 45, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 9)                   │             153 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 39,881 (155.79 KB)
#  Trainable params: 39,753 (155.29 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 44s 206ms/step - accuracy: 0.2521 - loss: 1.9712 - val_accuracy: 0.1552 - val_loss: 2.1640
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4307 - loss: 1.5898 - val_accuracy: 0.1552 - val_loss: 2.2377
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4507 - loss: 1.5336 - val_accuracy: 0.1552 - val_loss: 2.3274
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4613 - loss: 1.5092 - val_accuracy: 0.1574 - val_loss: 2.5219
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4671 - loss: 1.4604 - val_accuracy: 0.2993 - val_loss: 1.9727
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5016 - loss: 1.3970 - val_accuracy: 0.1707 - val_loss: 2.3528
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4915 - loss: 1.3899 - val_accuracy: 0.3126 - val_loss: 1.8711
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5192 - loss: 1.3327 - val_accuracy: 0.2927 - val_loss: 1.9647
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5057 - loss: 1.3715 - val_accuracy: 0.3126 - val_loss: 1.9726
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5341 - loss: 1.2853 - val_accuracy: 0.2395 - val_loss: 2.9275
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5649 - loss: 1.2573 - val_accuracy: 0.2528 - val_loss: 3.2425
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5535 - loss: 1.2672 - val_accuracy: 0.4412 - val_loss: 1.5653
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5523 - loss: 1.2518 - val_accuracy: 0.5233 - val_loss: 1.3825
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5467 - loss: 1.2554 - val_accuracy: 0.2772 - val_loss: 3.3199
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5381 - loss: 1.2849 - val_accuracy: 0.3326 - val_loss: 1.8916
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5258 - loss: 1.2759 - val_accuracy: 0.5011 - val_loss: 1.5021
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5615 - loss: 1.2240 - val_accuracy: 0.4612 - val_loss: 1.4451
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5575 - loss: 1.1994 - val_accuracy: 0.4102 - val_loss: 1.8750
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5637 - loss: 1.1975 - val_accuracy: 0.5144 - val_loss: 1.3371
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5832 - loss: 1.1796 - val_accuracy: 0.4501 - val_loss: 1.5455

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
#
# Model is underfitting. Loss is going down. Model Needs more training to improve accuracy.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

# Create an ImageDataGenerator for data augmentation

input_shape = (180,180,3)
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=40,      # Image rotation
    horizontal_flip=True,    # Flipping image along horizontal axis
    vertical_flip=True,      # Flipping image along vertical axis
    validation_split=0.2
)

# No augmentation here in validation set. Only scaling here
val_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.2)

img_class = ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# Load images from directory with augmentation applied to the training data
train_generator = datagen.flow_from_directory(
    data_dir_train,
    target_size=(180, 180),
    batch_size=32,
    classes = img_class,
    subset="training",  # Use the training subset
    seed=123
)

validation_generator = val_datagen.flow_from_directory(
    data_dir_train,
    target_size=(180, 180),
    batch_size=32,
    classes = img_class,
    subset="validation",  # Use the validation subset
    seed=123
)

img_size = (180, 180)

# Wrap the generator in a tf.data.Dataset
train_aug_dataset = tf.data.Dataset.from_generator(
    lambda: train_generator,
    output_signature=(
        tf.TensorSpec(shape=(None, *img_size, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, len(train_generator.class_indices)), dtype=tf.float32)
    )
)

validation_aug_dataset = tf.data.Dataset.from_generator(
    lambda: validation_generator,
    output_signature=(
        tf.TensorSpec(shape=(None, *img_size, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, len(validation_generator.class_indices)), dtype=tf.float32)
    )
)

train_aug_dataset = train_aug_dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
validation_aug_dataset = validation_aug_dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 1808 images belonging to 9 classes.
# Found 447 images belonging to 9 classes.

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
class_names = list(train_generator.class_indices.keys())

# Initialize a dictionary to store one example per class
images_per_class = {}

# Loop through batches to gather one example per class
for images, labels in train_generator:
    for image, label in zip(images, labels):
        class_index = np.argmax(label)  # Get class index from one-hot encoded label
        class_name = class_names[class_index]

        # If we don't have an example for this class, save it
        if class_name not in images_per_class:
            images_per_class[class_name] = image
        if len(images_per_class) == len(class_names):  # Stop when we have one example per class
            break
    if len(images_per_class) == len(class_names):
        break

# Plot one image per class
plt.figure(figsize=(10, 10))
for i, (class_name, image) in enumerate(images_per_class.items()):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(class_name)
    plt.axis("off")
plt.show()

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## Build Model
model = models.Sequential([
    layers.Conv2D(8, (3, 3), activation="relu", input_shape=input_shape, padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(16, (3, 3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(32, (3, 3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),

    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),

    layers.Dense(256, activation="relu"),
    layers.Dropout(0.5),

    layers.Dense(9, activation="softmax")  # 9 classes
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 180, 180, 8)         │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 180, 180, 8)         │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 90, 90, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 90, 90, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 90, 90, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 45, 45, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 45, 45, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 45, 45, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 22, 22, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │       7,930,368 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,070,265 (30.79 MB)
#  Trainable params: 8,070,153 (30.79 MB)
#  Non-trainable params: 112 (448.00 B)

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Training the model

# %%
# Training model with 20 epochs
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 54s 754ms/step - accuracy: 0.2370 - loss: 8.1144 - val_accuracy: 0.2058 - val_loss: 2.9299
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.2749 - loss: 2.1744 - val_accuracy: 0.2058 - val_loss: 5.5178
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.3530 - loss: 1.9258 - val_accuracy: 0.2058 - val_loss: 4.2622
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.3410 - loss: 1.8994 - val_accuracy: 0.2058 - val_loss: 3.3885
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 0.3533 - loss: 1.8664 - val_accuracy: 0.2170 - val_loss: 2.6326
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.3785 - loss: 1.8307 - val_accuracy: 0.2036 - val_loss: 2.1545
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 0.3431 - loss: 1.8264 - val_accuracy: 0.3400 - val_loss: 1.9555
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.3888 - loss: 1.7849 - val_accuracy: 0.2752 - val_loss: 2.1847
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.3706 - loss: 1.7573 - val_accuracy: 0.3132 - val_loss: 2.0005
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.3940 - loss: 1.7375 - val_accuracy: 0.2327 - val_loss: 2.1083
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 537ms/step - accuracy: 0.3938 - loss: 1.6883 - val_accuracy: 0.3602 - val_loss: 1.7343
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 35s 549ms/step - accuracy: 0.3888 - loss: 1.6935 - val_accuracy: 0.3311 - val_loss: 1.8885
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 537ms/step - accuracy: 0.3978 - loss: 1.6860 - val_accuracy: 0.2125 - val_loss: 2.3010
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.4076 - loss: 1.6615 - val_accuracy: 0.2371 - val_loss: 2.2261
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.4271 - loss: 1.6230 - val_accuracy: 0.1924 - val_loss: 3.0283
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.4492 - loss: 1.6051 - val_accuracy: 0.3579 - val_loss: 1.8191
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 529ms/step - accuracy: 0.4564 - loss: 1.5481 - val_accuracy: 0.3378 - val_loss: 2.0317
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.4358 - loss: 1.6036 - val_accuracy: 0.2617 - val_loss: 2.2141
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.4203 - loss: 1.6117 - val_accuracy: 0.3020 - val_loss: 1.8820
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 0.4338 - loss: 1.5753 - val_accuracy: 0.3378 - val_loss: 1.9453

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(20)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# After augmentation, score has reduced.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
from collections import defaultdict


# Initialize a dictionary to count the images per class
class_counts = defaultdict(int)
#class_names = train_ds.class_names

# Iterate over the dataset to count each class
for images, labels in train_ds:
    for label in labels:
        class_counts[class_names[label]] += 1

# Print the count for each class
for class_name, count in class_counts.items():
    print(f"Class '{class_name}': {count} images")
# Out:
# Class 'nevus': 288 images
# Class 'melanoma': 354 images
# Class 'basal cell carcinoma': 306 images
# Class 'pigmented benign keratosis': 374 images
# Class 'actinic keratosis': 88 images
# Class 'seborrheic keratosis': 61 images
# Class 'dermatofibroma': 77 images
# Class 'vascular lesion': 122 images
# Class 'squamous cell carcinoma': 134 images

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# seborrheic keratosis
# #### - Which classes dominate the data in terms proportionate number of samples?
# pigmented benign keratosis, basal cell carcinoma, melanoma and nevus

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (11.0.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.6)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/drive/MyDrive/CNN/ISIC/Train/"
import Augmentor
for i in class_names:
    print (path_to_training_dataset + i)
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# /content/drive/MyDrive/CNN/ISIC/Train/actinic keratosis
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x795DE0496A70>: 100%|██████████| 500/500 [00:04<00:00, 105.42 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/basal cell carcinoma
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x795D481377C0>: 100%|██████████| 500/500 [00:04<00:00, 102.42 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/dermatofibroma
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x795DF81CA8C0>: 100%|██████████| 500/500 [00:04<00:00, 102.28 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/melanoma
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x795D9D3E8D90>: 100%|██████████| 500/500 [00:14<00:00, 33.41 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/nevus
# Initialised with 373 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x795DE65F7970>: 100%|██████████| 500/500 [00:13<00:00, 38.45 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x795D93D4B6D0>: 100%|██████████| 500/500 [00:04<00:00, 103.16 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/seborrheic keratosis
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x795D487201C0>: 100%|██████████| 500/500 [00:07<00:00, 70.78 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x795D486CA410>: 100%|██████████| 500/500 [00:04<00:00, 104.79 Samples/s]
# /content/drive/MyDrive/CNN/ISIC/Train/vascular lesion
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/ISIC/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x795D487126B0>: 100%|██████████| 500/500 [00:05<00:00, 92.84 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024490.jpg_8f256105-e24a-4809-8c13-e4e043029580.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026737.jpg_0cbf3e4d-f95a-473b-b28e-9fc792c04bce.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025867.jpg_f77e66ad-585a-4b60-b53c-d010567f068d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025842.jpg_216a051a-5d40-48e7-ac6b-0fe50e20889b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027681.jpg_cf288644-71c1-4a97-b7e2-127ac0b6857b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026416.jpg_a260590f-0342-4142-8ab0-63d924d39eda.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027295.jpg_46238e67-25f0-4705-bae6-1f89c0325714.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024758.jpg_d27b3fdf-5ba3-4027-8e1a-896bc08a29a5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025312.jpg_b7e57814-92c0-469a-b2f6-883ad8ed51c9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025180.jpg_dcefe75d-ad92-4e3d-ba29-4980d9a98181.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026893.jpg_12d51012-c041-4864-94d1-bcd03a7bc484.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026827.jpg_f43c8524-5038-41f9-bf5f-4b2e7475409e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024947.jpg_a00c3689-9846-4204-b816-1c96f7c8d539.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026511.jpg_232a05a7-9a06-4f6f-87be-b406aaad1d2a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027394.jpg_7e2de486-27a7-4e75-b703-c8e8894fe875.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026477.jpg_bc93d731-4140-4a33-9589-6e0408b46bca.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028294.jpg_2a58d226-d6c8-4a2b-882b-84a650843041.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026280.jpg_14d11658-f23c-42d2-a4a2-8dd11068e46e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027875.jpg_eaa5c9da-c1fd-4c27-bc86-8156a144f19b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028209.jpg_e86be402-63c5-4914-9322-58514c6314d3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026205.jpg_c8822ca0-30b2-4842-bd9a-11a4d700b42d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024494.jpg_a73127df-ee4b-4772-827b-a2b625c46c95.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028662.jpg_ab286e03-0421-4e5e-8d6b-4baccf99e9cc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028180.jpg_96566406-942e-4a4d-9e93-4305f9c86520.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027151.jpg_399e4f6d-da78-44b3-b0a4-e81923701de2.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028511.jpg_9d9ccb36-83c3-4fc2-821d-c094a052db7d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028104.jpg_f07617c2-c669-44fe-bc98-1fa6850ec90a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024705.jpg_b77d3cf0-ffaa-419a-afa7-34df42dae372.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025885.jpg_20f3b921-bff5-4d07-b21b-57500de83933.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028628.jpg_dbe3aa2c-4a78-4829-876d-994b181bac14.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024786.jpg_21968759-96e0-4e51-afd3-d226bc592419.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027960.jpg_434db91d-4700-4044-b64e-e0ac76d2f796.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025275.jpg_6ed80429-d7f6-4dd2-805e-0128136d75ce.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025716.jpg_89d5a807-540d-4d7c-8f7c-971a9dbb212b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028490.jpg_bba885fd-1b0d-4d1b-b7e8-6a6681fdd086.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024773.jpg_dd5385fb-dde6-4b44-a3e0-7db28267f447.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028662.jpg_06cc89b7-2a84-4f47-8127-956d28aa4849.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027455.jpg_5a0a12dc-d2de-48b1-90da-49ae1c128f34.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027455.jpg_f4a52f2f-1b32-46c7-8110-b049f03ec4d7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027167.jpg_d0ed7aed-3768-48e1-8b6b-80565c9c0ded.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026675.jpg_7cdb4b61-5db4-4f50-bf03-80f0c03af0b3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026263.jpg_ea767239-2e57-4071-92ac-8253831e7a8e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027335.jpg_1f1980b0-622a-4c04-8f1d-671e2174760c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025140.jpg_7a208445-010d-481a-bf57-c30bfb474968.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025883.jpg_7ce8845a-9c2b-4a1c-9761-18a1d2967a68.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027354.jpg_c3b623f0-2415-4af2-9973-5b9058fc777b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026069.jpg_369cee60-cbc2-4a19-8c95-3957e922d339.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028607.jpg_d3e23a98-2b18-4e26-af8d-c488647377d7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025819.jpg_854d564d-c23f-4d97-bf12-2f182619721d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027559.jpg_8910ff0d-cffb-4958-836d-99d3fad571ef.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024505.jpg_89900bc0-cc8d-4845-848b-23ffb60b7ca1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025529.jpg_8ef4a022-7fae-4fec-857c-70d16d0155f4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025454.jpg_37fae704-e3f3-4738-ab89-c36261ce50be.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026335.jpg_30e70189-72f4-4c22-82a3-fb9a3ec990ab.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028236.jpg_a3b14b31-a9af-462b-ad3a-b44b7d126df3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026153.jpg_d6cc5c97-3af0-4041-9ad6-42c3c9fcb36b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027455.jpg_92e90093-f24c-4823-9ec3-3f94744d7c66.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025554.jpg_0fb88aea-51c5-4bee-acc9-35084f90cf3f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026623.jpg_6b6438a9-3c2c-4f77-b676-b4c1bcbe0fe5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027559.jpg_8cfca88f-9395-4a56-99ad-f90075d1b0e9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028236.jpg_5d4f2123-dbbb-43ca-ae39-b1ed96674906.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026044.jpg_5c1f0dea-0bc5-4122-89be-039b476138d0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025526.jpg_eadcd989-e198-481d-98df-19a87bd02818.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028223.jpg_86482a31-298e-494c-aa70-55deef5ab825.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026044.jpg_de2d63f6-2f25-466e-b734-8e4724cdfb17.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026378.jpg_b94762a2-0500-4b42-a768-2ea6475b1f9c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025879.jpg_f73c190d-91a0-4ecc-a699-f53df00c6dc5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024726.jpg_cd602fd8-6975-4cf7-a7ea-f4de3f3c13e8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027831.jpg_ee4ceeaf-7990-4cb1-9a94-2532d7f9541c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026556.jpg_ffc3290f-af9e-47dd-9a13-f1e90441826c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024871.jpg_ddc44fe4-d0fe-4fd4-b993-f19069c77833.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027320.jpg_42ca6261-8a12-4838-8a1b-e582e0ee6f54.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027680.jpg_3f9598e5-e52c-4425-b1f8-b8e679fe61f1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025716.jpg_fb25255e-92bc-4f7e-b7a0-d0162ec62353.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024774.jpg_66710ac4-d9cf-488a-94ec-1c55d3746784.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028165.jpg_94347502-bfbb-4cc5-a338-0c5ffed838e8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025431.jpg_4b82fca8-7bf5-44d1-8980-15694a1adbd9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027905.jpg_2476fe49-bc84-4148-9e92-fd37d6e8a2c0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025466.jpg_aecc3c07-bc3e-4dc9-a5cd-80f5d4233f78.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027451.jpg_86d6cb7d-0fae-4b57-a927-0c394b096236.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026737.jpg_cc90073e-d559-433c-af38-f51ad093553c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026661.jpg_e4e458a9-a497-4cdd-8c47-1c29543994fe.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027218.jpg_a539c82f-e789-4de5-8eb7-a70c8d407b60.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026775.jpg_598d1e27-e893-41a3-b998-13616d1c405d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026276.jpg_168f4f58-9199-401e-a6f1-df33e705a239.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028233.jpg_b6b55ff6-0e4b-4d78-a5a9-f3fdee99eed0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025819.jpg_929418d0-4860-4ab6-907a-3f1e42bf2254.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027053.jpg_76e90c1d-707b-4d85-8d8e-ae2456979186.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025086.jpg_1ce55535-8167-4a28-86ea-f89944eaef76.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024748.jpg_2af4791b-312c-4d3d-85af-e4efb5d4a969.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026514.jpg_b9a81558-b571-4d33-9bc7-7f63f781b5ed.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027006.jpg_90773ce3-4a8f-4d21-b489-67cb9eca262b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027960.jpg_0af81394-3cd3-4a95-b82e-cb7f21f7edf6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027068.jpg_66617f94-c4bf-48b1-9387-7fdbfb709fd0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026532.jpg_00cc436a-14df-4d2c-a162-6fb679338b6f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026443.jpg_a549d6fe-6aff-4060-b64e-6f63a0b7364e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027354.jpg_2d569f77-8ecd-41c8-b646-a75602aae27a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027083.jpg_8dbe5513-5b77-4e92-b316-7da68777aa31.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027680.jpg_8ceda530-82ca-42d5-adf1-3a8065c2000c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024708.jpg_a920c6b7-109f-4716-b7b3-2d7bd5590712.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028473.jpg_c2037baf-0fbb-4fe7-886d-65e39c357bc2.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027025.jpg_37b34eda-822d-473f-aef7-37e5f95229a6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027806.jpg_3c7f11d9-e6a1-4f34-af55-b4f2bb157a61.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025699.jpg_347aad19-41e1-4dcb-8ec9-1c02e0d0fe31.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025984.jpg_8ccd0b6b-4644-4c65-a341-bcccc897a064.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025623.jpg_0aeccec1-46a5-4b2e-984e-cb630127a062.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024758.jpg_0c64b3b3-f1e6-42a3-9bd2-89e1ef41bbf6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025805.jpg_6e71fb54-48ed-43c6-b868-62cfbb68d788.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027760.jpg_57f2de79-faea-4ed2-8afb-e3667539e049.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027735.jpg_cca4991d-4b3b-4a6b-9aa7-151bc6c2f9b0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026871.jpg_74992c52-bf85-4527-b157-d1fb040f9135.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024672.jpg_ca375e32-d8fc-4276-aa78-a19e81f4ed55.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025753.jpg_5bc9fc03-40bd-488d-8a74-edce11fce994.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027584.jpg_deaef541-c230-427b-82b5-824ae4adc845.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027996.jpg_537e83b9-9820-492b-ae8e-734c347965f3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025575.jpg_6d3b4fc5-7901-4a61-bd65-4105f1a77b5d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025099.jpg_ae580651-0b6f-43f8-bb0a-c52ef889e077.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025431.jpg_2814fde4-3f87-4b21-bfaa-ab9a59491714.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028386.jpg_84150730-df58-4695-9d65-cb65b5a01eb9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027527.jpg_47d48ba8-b170-45d0-b208-cfe53af134d4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025484.jpg_fc74c0d4-fe1d-4f45-8a51-ac4b8bdd484e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027354.jpg_ede3158a-f82b-484d-bc86-20c09e654ae8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027969.jpg_b375e1f3-1c23-43dd-a571-ba5423598858.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026444.jpg_42aec70b-2790-4046-91d7-49f232b47b1d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024883.jpg_bfd4653e-5a92-4e24-92fb-a94ec492fb91.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028497.jpg_5af32438-3ce7-4788-b221-518a705feb32.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025716.jpg_80ec1a61-b74e-4bbf-b091-72407ffafa45.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027991.jpg_32785bfe-dc7e-469c-8274-1712c40c339f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025885.jpg_dda8db4d-721b-4082-bd79-b8c203dc0801.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027006.jpg_247dbf95-7f44-4dd4-89fe-a1e6e6c438d8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025879.jpg_1a4a866f-bfc1-4df4-a3a6-2054d2db5c46.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025378.jpg_fe49c381-ad41-4586-9e6b-5f5e37503d1b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025032.jpg_abd26d5f-4613-4709-98ca-9aa8b4c147fe.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024839.jpg_40adb33b-4543-45f5-9482-d391a49e9e5e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027754.jpg_0827bc72-b40f-4c9a-84bc-8124cec1b7fc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024881.jpg_7c016a76-799f-4733-879c-94d94d808961.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025099.jpg_d1efc9c5-b948-4b40-b2b4-dbc1cf37bcd9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026871.jpg_fac05774-93b7-4102-b48c-66c72062541c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026422.jpg_447382e3-381b-4e2a-9142-1f1d21753977.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027042.jpg_06c3f0c5-94d6-4e2f-a415-629c9d671cb5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025339.jpg_54a90a90-a066-41b5-a196-d571f1e2ff51.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028376.jpg_f4fb72ad-05b9-4271-a061-f1195ae3b6eb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025075.jpg_e7367d47-cb58-43ba-ab91-f70d39d1fd14.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027905.jpg_ba19bc7f-ad2d-4687-ae52-b7411a1a2946.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025642.jpg_35f054d9-45ee-4cfd-ba42-25adeeaf9781.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025470.jpg_e2226e88-f1e6-4f6d-b054-621e8afc72a5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027192.jpg_3628a2ac-5980-4ad5-83da-118cd01db525.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024758.jpg_3da07dfd-9349-4701-8222-9e982bbccbc1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028229.jpg_1fa55066-5895-49a2-90e1-614c06d2ef60.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025297.jpg_f52db010-c5fd-4963-a1da-8c9f528f7e5d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027154.jpg_f19ca514-29b8-48a7-bf06-e803edb9e698.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027151.jpg_58f606e7-cdf4-4996-a72b-bfa27da933f0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027437.jpg_4acaf39f-aff9-4649-8ca4-ba760f365720.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027354.jpg_dc93ef05-ad7f-41b4-a401-035506a5afaa.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025337.jpg_7f9696f2-ac6e-4d66-aebb-cd2b315b2fd9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025063.jpg_588d02cb-cd9c-40e9-a825-a2f5affee65b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026631.jpg_9ab3bf66-ff40-47b0-837b-9b55fc450f05.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025758.jpg_38c2caff-0508-49a7-96b6-0c4330e882f8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026775.jpg_db8bdb94-40d3-4712-8934-2f31dc4c292a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025767.jpg_d7a4d920-2a74-4707-841a-d51e8e9c002d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025345.jpg_c88d055b-162d-40ca-b2d4-bc23a8b9e8a4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026769.jpg_da78bf06-ada5-42c0-baa6-7b121db6cbfc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026159.jpg_26c321ad-3f14-44b6-9240-e261c8d4e25f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027370.jpg_f0fadc9a-91f9-43ac-a363-a5cef37b1cb1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026728.jpg_1e635131-20bd-49f8-b6db-99c6b0911137.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028080.jpg_e1b31ccc-669f-4fa5-b9b5-168f0964888c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025209.jpg_79ebf3d4-e0d4-4a3a-acf3-c2f7c6d0cbb9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026072.jpg_a13897cf-b44a-48ab-875e-123ef70e2535.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027355.jpg_b9ef3e77-8f54-480e-b0d8-06daa422bc9d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024970.jpg_b855ca74-90d9-4abc-9287-1dac961f3860.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026679.jpg_8b691847-f73f-4e79-a573-4259ce553044.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028656.jpg_0c644377-f534-48f4-8d96-95168599552a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026867.jpg_e94646ae-b2fe-465d-a0f5-eb2142c91ea7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026539.jpg_a6fd72c3-1f88-4b9c-98ab-4a877a8befa5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027374.jpg_dd58d8ac-e960-4435-8e45-1824efaf13f8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025339.jpg_3d1dcddb-3abb-417d-b776-cca8f6b77f75.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028404.jpg_00355c0d-a947-4a42-9df2-a29571b6f546.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026493.jpg_6655081d-acc5-4f40-b849-da6b4e5c7796.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025627.jpg_427a93c4-23a2-482c-a81a-d84610bf3159.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027006.jpg_9c224313-bb69-4d2a-addd-3c01031ba251.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027681.jpg_3ad8c004-6d97-4d3b-9845-47195a146091.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025883.jpg_16bca1b6-c321-4df5-a094-e48ccab1e5ce.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026737.jpg_94545a98-c418-4cde-8087-11f4c80f61d1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026787.jpg_9d3c24bc-e12b-4b68-8cad-d584cb36b4f7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028650.jpg_85182065-71e5-4e77-9224-cdce7c8f3252.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027026.jpg_fcebee61-6c2e-4d54-8644-38e830e018a2.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026205.jpg_f4a1470d-f100-4289-b325-a36f312fa7ed.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026843.jpg_fe9e1fae-7f31-4fc2-b2ec-9637f6abb2b3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027606.jpg_e0f192e8-0513-4435-a32b-f95d9a5df762.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026316.jpg_9ae25735-59bb-4aaa-9ecd-702ae91e87e1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025623.jpg_eb133b20-3487-477f-a407-0374828f12da.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027320.jpg_ee4a7616-e9ec-43b8-a5b6-08c8f3af4d0a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027355.jpg_fbecfcae-6729-43cd-8483-d32dc09966dc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025209.jpg_7f31c88c-14d6-454c-b84d-3daeee09e96e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026530.jpg_fbb3e74e-fcb8-4fd3-a509-1ddcddf5dca3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026895.jpg_460841f3-8c54-442f-be8e-cc5003afccbb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026714.jpg_60139040-4502-4a01-84eb-21f3a2afc52e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026262.jpg_ee1a9f93-3c31-4666-81d5-a8ec111a7821.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027326.jpg_0b8bd1e5-7830-4771-9dae-1718b8056cc4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025297.jpg_4cb7b710-b508-4d3b-b237-92021d04dee2.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027713.jpg_0a9feafc-0ce1-46fb-ab20-f8d690877c97.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026553.jpg_9f1cddb9-6082-4024-aa28-87b3bfb2af74.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026511.jpg_36aad88b-5484-46c4-bcac-554cb209d483.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026717.jpg_1d15b8f4-482b-4e76-9f85-d64d88de6fe3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026623.jpg_bbe9e4cb-91df-4270-bdbd-21c0f6247ed8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027760.jpg_b71789bf-5e15-4e6c-9863-8c54c064df4c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028100.jpg_fbee686e-de69-41f1-8b9d-73ab847627ac.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027954.jpg_601dffd4-38e6-4edf-bd87-de6d039863a0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024773.jpg_ee032f64-169e-412a-bd42-b9b385e02ba6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025856.jpg_d24710eb-3707-4eda-9142-4be034a1fe9d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026958.jpg_0b0515bd-d4a5-479b-8b05-28025f0d6440.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026606.jpg_9d49dd4d-760c-4244-8cec-8fccfc75cdda.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027770.jpg_a761bc3a-ff20-415b-a1fa-af0aa3a3534e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025016.jpg_d4f8d48e-9c88-4fd7-8d50-7f189972073b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027042.jpg_5612b071-e845-4dca-a2f9-f5c5a777193e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024726.jpg_d8e8e2fd-bb72-4d38-92e2-9532f4237070.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027018.jpg_50955713-9cce-4d52-b34f-d35a592f250c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027706.jpg_88587cf9-bcb5-44c2-a372-1729b9e7536b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028124.jpg_3437afcd-7d0d-4a7e-a1fb-eed18b9084f6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026526.jpg_487a64bf-dc35-4836-a759-8077a598dcfb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028354.jpg_c490679e-86fb-46d6-be94-d59e642212c0.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024726.jpg_b918ad25-b127-448f-bd5a-d951afd1a5d3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028593.jpg_9a262b6f-4209-4b12-a40b-7262dbb30f96.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024970.jpg_e3d3383c-78d6-42c4-8dc2-b0dc5bc8f884.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027064.jpg_9f21ca58-51e1-45e5-b733-5c751b3b8756.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026530.jpg_96d64e76-c87e-4b5f-bcfc-7a9f11320c21.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024623.jpg_7b79e5c4-c7b1-4fde-8bfd-ed1b48bd4de9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027982.jpg_880cbd47-9e65-463a-a9c7-bcf712a82164.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028264.jpg_26ad8af9-cb60-4cc7-b797-1ee513acc991.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028555.jpg_55fc8304-708b-4a0b-b3e2-a986e4528328.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024772.jpg_ab2408cb-0861-4096-993a-6ddf88d848f4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026444.jpg_7a9cbf7e-32fb-496d-b751-229bd9365d26.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026955.jpg_c0557647-96ea-4dca-b972-5b46b8f4cac5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027584.jpg_26048817-dcbb-47dc-a6c9-f368f3adfc05.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025743.jpg_38e501b2-361b-4bb4-adc4-629173e83f6d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024740.jpg_db2322ea-0c27-46cc-898d-3761d6298559.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027954.jpg_a4637a6b-a2e3-4d24-9e96-27cf6180b7c5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027509.jpg_6304a282-c9ed-4734-9dab-798bc880872a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026153.jpg_af22b0b4-2ab5-4867-91b2-6d5ed11fb300.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028473.jpg_5a04edb6-04d1-45c7-b243-bee70e3ba961.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027826.jpg_0c6a7c28-3f15-42c1-a184-22ec4c4f2015.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024760.jpg_d8631843-2619-49e6-a023-ef5bae830169.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025209.jpg_927d5754-1208-47d9-8a75-b9422a46499e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026311.jpg_db612694-80b7-4e84-a274-c39c199dbcfa.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028662.jpg_e2528322-71a3-444d-8219-05776c8623f6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027218.jpg_d13fde8d-0505-43df-8c8d-2f287c3229c1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025985.jpg_9a8bbee0-c4f9-4dfb-98d3-926157f27fd6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025209.jpg_083ce5e8-76eb-4a64-9cf9-40ccd63826ed.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024626.jpg_c78652a0-260d-442a-aca1-0086127d8b49.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024581.jpg_1ac4260e-2b05-4160-9cfb-81e2e6e6c341.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025805.jpg_880ada15-c79b-4cf1-b68e-e9daa94ffbb7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025326.jpg_fcc95f27-636f-49d0-a240-7952658048eb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027713.jpg_f4b85e30-0e24-4f47-bd2d-a488de520b02.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027388.jpg_846263f0-38ab-41c9-a6d9-8969524e8a19.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027905.jpg_ef971442-8d19-4237-9079-9354bb0f3b42.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024761.jpg_274e5cce-bb11-4ab6-8cdf-ac6e7860d9ba.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025554.jpg_118515f1-fd96-409e-a0db-760a1df97d30.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025781.jpg_d4cbf65b-bdc0-464a-b127-23ff201bab85.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024839.jpg_113853c7-a3a4-4245-a7e9-2bffe5469920.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028043.jpg_9e7e1347-9dcd-44de-a93a-903049066c09.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026511.jpg_5ef1cbc3-5957-4225-a363-4a2aafd99882.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026262.jpg_524f32c5-53d1-499f-8105-fe71507792ca.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028650.jpg_655e02b6-e0ef-441b-94ab-b7a1a142bf73.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027326.jpg_f955f30f-bdae-4c07-aa75-de023ff99871.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026907.jpg_e1374334-77ef-4167-af6f-eba69f51d7fe.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025431.jpg_a22b0add-7f7c-4fb6-b2ee-2e476bc75da7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028043.jpg_6dd0657c-374a-450e-b9cf-5d014638d00a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024592.jpg_a94bffc3-4632-46d7-b4e1-411c8f832a01.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026511.jpg_30818285-6070-4d3e-b9e5-f7a1f559c19e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028593.jpg_fe57ee1e-236b-40c5-9580-57e179064021.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024709.jpg_ff128543-5ffa-4388-9f63-7275d6822c3c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027167.jpg_a6c50f1f-916d-42bf-ae83-165a0268adea.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025016.jpg_afba4736-1219-4fcd-8fe9-3ee634f0c98b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026298.jpg_45bdc983-72b3-4b3b-8bf3-d122098674c9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028331.jpg_a1ba1942-19e7-4bbc-a165-07336b457a4e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026775.jpg_7c64b758-1beb-4a28-81c0-14274a10b3fb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027735.jpg_9d8627a8-5a3c-42e6-94d2-50b2db175042.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024774.jpg_82be0ecb-6f73-41fe-8d53-9b78cba70863.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028650.jpg_70b0144f-c9d7-48c2-bfd7-d83c8099290d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026955.jpg_ec1ea67b-6e13-4c42-87c0-455b3fdbc6cc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025038.jpg_b2494cd5-5843-474f-884f-87ee4b4ad900.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027893.jpg_476ff830-fdca-479c-961f-7a3c3b3eb932.jpg',
# ...
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027550.jpg_30e99ce0-a749-4d0b-9f2a-604add91589a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0033869.jpg_c8a60e1f-6925-4248-b89e-921e135fcc00.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025130.jpg_f09b06df-047f-4458-be20-2eaf5274054d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029851.jpg_3b47679b-994a-4ed1-bc31-9d4f1cf0a362.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030487.jpg_b28a939f-4209-4bf7-bc1b-d3f6dd6f8fa8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031738.jpg_453837cc-7484-490b-9b55-427a299a1248.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0024843.jpg_66f5e1cd-e56e-4492-b889-c30afc59aac6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030827.jpg_2d49cb39-0548-4310-aa75-7e6f2aacbb6d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027294.jpg_cf8a5c71-1be3-4e80-aad7-4ecd7dcf3eaf.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027719.jpg_1bf668b9-ca6a-4e79-bfb3-8b460186d0dc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029043.jpg_2e25648e-3418-4e3f-a60f-bcacfa1fd9a3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0033536.jpg_587d9ff7-f500-4c1f-9fbe-99934f140d53.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025029.jpg_df285249-c76f-4728-b591-91afa6b469aa.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029715.jpg_de10d8f9-20fe-4437-9fba-964ca9284fac.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025808.jpg_355b70e1-e70f-49ce-b71b-5904418a18fe.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031012.jpg_b5433c37-7ea0-4a76-bd87-2cbf190b01fb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026206.jpg_91aa170b-846a-4c18-ac7b-976927ec9fea.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027577.jpg_32267e42-39bf-44dd-84a7-dda2f32858ac.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028795.jpg_87a0d4da-df46-4940-8f56-503ca0a3bf0d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029067.jpg_036ee956-bb63-475a-b39d-857f25f01821.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031692.jpg_7a3cc8d7-ea1e-4a87-b185-eddfc9ee695c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030387.jpg_5d358276-f302-4e6e-a933-f7bb75cb5152.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030844.jpg_21fd8121-1919-4908-a404-ba2c3dd14183.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031012.jpg_4b892efe-52e1-4970-9300-94fb1e42a019.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028816.jpg_ca8c6df6-6045-4eec-8e22-e2631cf19f4f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031044.jpg_e982184b-4f9a-401d-ab5e-5f0761c081fb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0024710.jpg_f2016eb5-ebd0-4af8-9a0a-b90e604d6eb3.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031672.jpg_52a6dd22-9810-4f8b-8dfe-bef9fe2346f9.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025182.jpg_4f9f8923-01d3-4c38-88d5-908130ceb25d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027529.jpg_f201fbc7-ae52-4349-ae08-ee6963dd3f18.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030375.jpg_35954cc1-73d8-45ff-aada-04a9c98d62aa.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032277.jpg_9925e07f-b61b-458d-bc5d-c8ab688b2d6b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027767.jpg_6e5bfe0e-9544-4720-b339-969f78cdc008.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030280.jpg_d56c5f9e-a10e-47a7-b930-cf76a8b33b31.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0033000.jpg_bfe57044-1f3e-4805-81b0-48adec07e0c1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025089.jpg_1f056a8a-a4b7-43aa-98c8-1d2379db4b15.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027930.jpg_3709fe59-1ef7-4540-a66c-f614282d560e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027303.jpg_92b8157f-0e8e-4e37-8d81-594640d080a4.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032173.jpg_b3e240b5-dc30-489c-b3c4-08593d1b486e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026362.jpg_c39ba569-5ab6-4e0b-ae02-ffdd78c88ccd.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025696.jpg_e5bdca0f-6d41-4482-a702-7863e8852b57.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031929.jpg_ba1ff998-8d8b-4fc4-a396-2805162ea0e8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031874.jpg_9e8c7ee5-2031-435a-9924-8192d979ecab.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030986.jpg_8cf0a24e-7cf1-4f68-978b-afec32ce973e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027506.jpg_f34194a2-c06c-40fc-b0e3-afdfe2938d01.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031286.jpg_ab29f290-dcfe-4ec8-a002-8eebd8f78d53.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025029.jpg_aa6d562c-20bb-488c-a590-88b6768e49b7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025029.jpg_cd1a06c0-6bbd-425e-b9cc-bea77cd6472a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031743.jpg_0cdd3c60-454a-4d47-9a08-35b9e55948e7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026720.jpg_805a1b01-edd9-4772-af14-872342c46c08.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031570.jpg_1bb1ca18-7f6b-4c91-bf1e-1119461ec46b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031672.jpg_f7667320-c07e-45b2-98e9-86b7da9e6540.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026466.jpg_f9a1de18-e4ed-47dc-887f-774d7b49e31f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031927.jpg_dd70b6bd-dc14-48e6-8410-20598aa2a082.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029462.jpg_b1fd022a-38c9-4e00-932d-be6b2d5dd55b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031578.jpg_fe28ce44-f5ed-4bdb-aa86-fd0511c4b161.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026872.jpg_6a6e29c5-280f-4539-98f6-7ada6c178af1.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031929.jpg_a729f6fb-c907-4c35-b1b5-9697b3aa779a.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030191.jpg_6e816bbe-bf50-44c4-98d5-12a8945524fe.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030714.jpg_4b07f03f-9f76-4994-ad25-e2b75b37c949.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029638.jpg_3cba2b55-8221-4ef1-99fd-6e44056bb0f5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025247.jpg_df807dfd-a5cc-4ce0-9da3-e7a3c1cb3472.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030986.jpg_b030234c-871d-4de1-a144-5d7c28da33bd.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030297.jpg_848d2dda-9695-4cfa-8901-b31c66009b78.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031570.jpg_d223de99-8950-4900-892b-0d36cb00f6c7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026981.jpg_340ffba5-e941-4e0a-a06d-d19167d37e9d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032349.jpg_69cd054d-04fe-4dc2-931b-1285f12abcc8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029043.jpg_462991f7-f214-43d3-a65f-b6aaf7bda412.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031578.jpg_8a5400c7-e86f-4132-8d86-4fc8bec3f59e.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030175.jpg_81a7a50b-4efc-4f03-93e8-4fbdcf422452.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028763.jpg_91e0f1da-12d9-4305-86fa-ae8b8d6b1cab.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026362.jpg_43a0b198-20a5-4e13-b268-7d9ad345950b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027529.jpg_dacff16d-493f-4e65-bfb4-b40888c1280f.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027577.jpg_af6fa286-5b69-4343-91da-c3941ede46ed.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025069.jpg_b9cbef1b-9159-4341-abbd-574a3eae7809.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0024946.jpg_8ce4f900-2f6a-4944-9951-5a54a9fb70bf.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025350.jpg_34788f44-c0d0-45e5-95c5-645890b83953.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030297.jpg_70f1a120-a08c-4080-b4d1-2283eaa3fcd7.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030714.jpg_4971c2ed-7265-4fe8-b564-45c3ac734cdc.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025808.jpg_b5944242-f0e0-451c-815a-5996655ebd8c.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025247.jpg_03979b5e-a695-462f-85ae-0b78a9d242f5.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026492.jpg_fce7ce0f-da57-4fef-9ad8-f72703c97f04.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027303.jpg_0d30fbe8-9743-4e7c-bafc-9d79965614d6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030714.jpg_9cade8f8-a12b-4e78-b6d7-4f0d66cd85b8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030785.jpg_88e6801d-6055-417e-be6d-31e2b9beb16d.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025029.jpg_a4886f5d-5d9f-48cb-9498-b974c13045d8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027506.jpg_8e0b7a8b-1b81-4a9e-b98f-c4a997a633fb.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029462.jpg_08738df3-4182-4b36-94d6-cf252ae84e74.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030602.jpg_8c4994ff-02fd-4161-af5b-ef5e6d36503b.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0033869.jpg_39819fa1-d942-40cd-8108-3c2a41b0b5a8.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032014.jpg_50b099df-8c72-4ac7-be12-adb27ef9fbb6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025029.jpg_4bb57aeb-7442-4853-b0db-560700421389.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027529.jpg_c1f8349e-7a1f-4790-a15a-80ee8fc6ae92.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032238.jpg_75f83307-74b1-43cc-9c9d-4ddfcec4b937.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031211.jpg_ebde7e3b-56e4-41e8-b4f7-d933db9573a6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027047.jpg_47b7b94e-ec83-4de8-8a78-8b77aa1ae8c6.jpg',
#  '/content/drive/MyDrive/CNN/ISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027047.jpg_8648ff3d-8674-440b-ac98-dd8ac23fdf04.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    500
# squamous cell carcinoma       500
# dermatofibroma                500
# nevus                         500
# seborrheic keratosis          500
# basal cell carcinoma          500
# melanoma                      500
# vascular lesion               500
# actinic keratosis             500
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,           # 20% for validation
    subset="training",              # Specify this subset is for training
    seed=123,
    image_size=(img_height, img_width),# Resize images to (180, 180)
    batch_size=batch_size
)
# Out:
# Found 6755 files belonging to 9 classes.
# Using 5404 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6755 files belonging to 9 classes.
# Using 1351 files for validation.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## Build Model
input_shape = (180,180,3)
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=input_shape, padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(16, (3, 3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(32, (3, 3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),

    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),

    layers.Dense(256, activation="relu"),
    layers.Dropout(0.5),

    layers.Dense(9, activation="softmax")  # 9 classes
])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_11 (Conv2D)                   │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 180, 180, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 90, 90, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 90, 90, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 45, 45, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 45, 45, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 45, 45, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 22, 22, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 512)                 │       7,930,368 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,074,489 (30.80 MB)
#  Trainable params: 8,074,329 (30.80 MB)
#  Non-trainable params: 160 (640.00 B)

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
epochs = 30
batch_size = 32
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3,verbose=1,factor=0.5,min_lr=0.00001)

## Your code goes here, use 30 epochs.
history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds, callbacks=[learning_rate_reduction]
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.2076 - loss: 4.3809 - val_accuracy: 0.1621 - val_loss: 2.4440 - learning_rate: 0.0010
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3037 - loss: 1.8544 - val_accuracy: 0.3486 - val_loss: 1.7727 - learning_rate: 0.0010
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3784 - loss: 1.6297 - val_accuracy: 0.4434 - val_loss: 1.4494 - learning_rate: 0.0010
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4284 - loss: 1.4859 - val_accuracy: 0.1399 - val_loss: 5.1521 - learning_rate: 0.0010
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5039 - loss: 1.3204 - val_accuracy: 0.5751 - val_loss: 1.2365 - learning_rate: 0.0010
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5545 - loss: 1.1918 - val_accuracy: 0.6099 - val_loss: 1.0319 - learning_rate: 0.0010
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6119 - loss: 1.0442 - val_accuracy: 0.6358 - val_loss: 1.0438 - learning_rate: 0.0010
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6692 - loss: 0.8961 - val_accuracy: 0.6721 - val_loss: 0.9331 - learning_rate: 0.0010
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7100 - loss: 0.7885 - val_accuracy: 0.6603 - val_loss: 0.9825 - learning_rate: 0.0010
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7441 - loss: 0.6979 - val_accuracy: 0.5774 - val_loss: 1.3547 - learning_rate: 0.0010
# Epoch 11/30
# 162/169 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7817 - loss: 0.6338
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7817 - loss: 0.6330 - val_accuracy: 0.6107 - val_loss: 1.1884 - learning_rate: 0.0010
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8279 - loss: 0.4806 - val_accuracy: 0.7794 - val_loss: 0.6385 - learning_rate: 5.0000e-04
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8505 - loss: 0.3929 - val_accuracy: 0.8053 - val_loss: 0.6009 - learning_rate: 5.0000e-04
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8622 - loss: 0.3514 - val_accuracy: 0.6484 - val_loss: 1.1669 - learning_rate: 5.0000e-04
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8749 - loss: 0.3297 - val_accuracy: 0.7905 - val_loss: 0.6448 - learning_rate: 5.0000e-04
# Epoch 16/30
# 163/169 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8909 - loss: 0.2960
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8908 - loss: 0.2965 - val_accuracy: 0.7779 - val_loss: 0.6862 - learning_rate: 5.0000e-04
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8963 - loss: 0.2556 - val_accuracy: 0.8098 - val_loss: 0.5912 - learning_rate: 2.5000e-04
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9200 - loss: 0.2289 - val_accuracy: 0.7587 - val_loss: 0.7854 - learning_rate: 2.5000e-04
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9129 - loss: 0.2324 - val_accuracy: 0.8342 - val_loss: 0.5258 - learning_rate: 2.5000e-04
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9228 - loss: 0.2084 - val_accuracy: 0.8209 - val_loss: 0.5711 - learning_rate: 2.5000e-04
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9239 - loss: 0.2150 - val_accuracy: 0.8001 - val_loss: 0.6818 - learning_rate: 2.5000e-04
# Epoch 22/30
# 161/169 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9306 - loss: 0.1804
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9304 - loss: 0.1807 - val_accuracy: 0.8090 - val_loss: 0.6222 - learning_rate: 2.5000e-04
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9400 - loss: 0.1543 - val_accuracy: 0.8290 - val_loss: 0.5378 - learning_rate: 1.2500e-04
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9332 - loss: 0.1610 - val_accuracy: 0.8268 - val_loss: 0.6155 - learning_rate: 1.2500e-04
# Epoch 25/30
# 163/169 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9334 - loss: 0.1602
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9336 - loss: 0.1600 - val_accuracy: 0.8320 - val_loss: 0.5827 - learning_rate: 1.2500e-04
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9427 - loss: 0.1504 - val_accuracy: 0.8253 - val_loss: 0.6043 - learning_rate: 6.2500e-05
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9472 - loss: 0.1348 - val_accuracy: 0.8364 - val_loss: 0.5703 - learning_rate: 6.2500e-05
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9436 - loss: 0.1455 - val_accuracy: 0.8327 - val_loss: 0.5672 - learning_rate: 6.2500e-05
# Epoch 29/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9491 - loss: 0.1282 - val_accuracy: 0.8327 - val_loss: 0.5611 - learning_rate: 6.2500e-05
# Epoch 30/30
# 163/169 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1392
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9478 - loss: 0.1395 - val_accuracy: 0.8342 - val_loss: 0.5505 - learning_rate: 6.2500e-05

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# Yes Model is not underfitting now. After handling class imbalance, score has improved significantly, training accuracy is 0.94 and validation accuracy is 0.83
